# %% [markdown]
# # 02 - Preprocessing & Dataset Validation\nValidates cloud masking, radiometric normalization, and patch alignment.\n

# %%
from satellite_srm.preprocessing import RadiometricNormalizer, CloudMasker
from satellite_srm.datasets import DatasetValidator

validator = DatasetValidator('data/interim')
res = validator.run_checks()
print('Validation Status:', res['status'])
print('Inspected Pairs:', res['total_pairs_inspected'])
